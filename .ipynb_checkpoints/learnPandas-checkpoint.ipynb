# %%
import pandas as pd
pd.__version__
# Out:
# '0.25.3'

# %%
arr = [0, 1, 2, 3, 4]
df = pd.Series(arr)
df
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
d = {"a":1, "b":2, "c":3, "d":4, "e":5}
df = pd.Series(d)
df
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
dates = pd.date_range('today', periods=6)
num_arr = np.random.randn(6,4)
columns = ['A', 'B', 'C', 'D']
df1 = pd.DataFrame(num_arr, index = dates, columns=columns)
df1
# Out:
#                                    A         B         C         D
# 2020-01-16 19:48:03.775215 -1.924867  0.043890  0.421779  0.344935
# 2020-01-17 19:48:03.775215 -0.520228 -3.129167  0.100689  0.448522
# 2020-01-18 19:48:03.775215  0.607684  0.312604  0.248148 -0.529778
# 2020-01-19 19:48:03.775215  1.037117 -0.342924 -0.306290  1.028170
# 2020-01-20 19:48:03.775215  0.543368 -0.928099  0.609807 -0.862348
# 2020-01-21 19:48:03.775215  1.384166 -0.496514  0.873494 -0.311432

# %%
# df = pd.read_csv('test.csv', encoding='gbk, sep=';')

import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# animal      10 non-null object
# age         8 non-null float64
# visits      10 non-null int64
# priority    10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.iloc[:3,]
# df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.loc[:, ['animal', 'age']]
# 方法二
# df[['animal', 'age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.loc[df.index[[3, 4, 8]],['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df[df['age'] > 3]
# Out:
#   animal  age  visits priority
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# i    dog  7.0       2       no

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df['age']>2) & (df['age']>4)]
# Out:
#   animal  age  visits priority
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# i    dog  7.0       2       no

# %%
df.loc['f', 'age'] = 1.5

# %%
df['visits'].sum()
# Out:
# 19

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %%
df.loc['k'] = [5.5, 'dog', 'no', 2]
df = df.drop('k')
df
# Out:
#   animal  age visits priority
# a    cat  2.5      1      yes
# b    cat    3      3      yes
# c  snake  0.5      2       no
# d    dog  NaN      3      yes
# e    dog    5      2       no
# f    cat  1.5      3       no
# g  snake  4.5      1       no
# h    cat  NaN      1      yes
# i    dog    7      2       no
# j    dog    3      1       no

# %%
df['animal'].value_counts()
# Out:
# dog      4
# cat      4
# snake    2
# Name: animal, dtype: int64

# %%
df.sort_values(by = ['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age visits priority
# i    dog    7      2       no
# e    dog    5      2       no
# g  snake  4.5      1       no
# j    dog    3      1       no
# b    cat    3      3      yes
# a    cat  2.5      1      yes
# f    cat  1.5      3       no
# c  snake  0.5      2       no
# h    cat  NaN      1      yes
# d    dog  NaN      3      yes

# %%
df['priority'] = df['priority'].map({'yes':True, 'no':False})
df
# Out:
#   animal  age visits  priority
# a    cat  2.5      1      True
# b    cat    3      3      True
# c  snake  0.5      2     False
# d    dog  NaN      3      True
# e    dog    5      2     False
# f    cat  1.5      3     False
# g  snake  4.5      1     False
# h    cat  NaN      1      True
# i    dog    7      2     False
# j    dog    3      1     False

# %%
df['animal'] = df['animal'].replace('snake', 'python')
df
# Out:
#    animal  age visits  priority
# a     cat  2.5      1      True
# b     cat    3      3      True
# c  python  0.5      2     False
# d     dog  NaN      3      True
# e     dog    5      2     False
# f     cat  1.5      3     False
# g  python  4.5      1     False
# h     cat  NaN      1      True
# i     dog    7      2     False
# j     dog    3      1     False

# %%
df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean')
df
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-54-7dd0b25b6218> in <module>
# ----> 1 df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean')
#       2 df
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6087             dropna=dropna,
#    6088             margins_name=margins_name,
# -> 6089             observed=observed,
#    6090         )
#    6091
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     303         if f is not None:
#     304             if callable(f):
# --> 305                 return f(*args, **kwargs)
#     306
#     307             # people may try to aggregate on a non-callable attribute
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate
